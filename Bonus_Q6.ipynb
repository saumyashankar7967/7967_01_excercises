# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Data/movie_metadata.csv")
df=pd.read_csv('Data/imdb.csv',escapechar="\\")

# %%
df1=df.dropna()
# relationship between the length of a movie title and the ratings
df_plot=df1.filter(['imdbRating'],axis=1)
df_plot['length']=df1['title'].apply(lambda x: len(str(x)))
sns.jointplot(x='length',y='imdbRating',data=df_plot,kind='reg')
corrmat = df_plot.corr()
print("Following correlation will show the correlation b/w ImdbRating and length")
print(corrmat)
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
# Out:
# Following correlation will show the correlation b/w ImdbRating and length
#             imdbRating    length
# imdbRating    1.000000  0.103573
# length        0.103573  1.000000

# %%
#Insight0
#From the above correlation matrix its clear that there is almost no relation between length and imdbRating

# %%
data_groupby_gross = data.groupby(['title_year'])['gross'].count()
data_groupby_gross.plot()

# %%
#Insight 1
"""
As we can see above,gross amt increased by a great amount probably because of technological advancements happened in the
film industry
"""
# Out:
# '\nAs we can see above,gross amt increased by a great amount probably because of technological advancements happened in the\nfilm industry\n'

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (12, 6))
sns.countplot(x="language", data = data)
ax = plt.xticks(rotation=90)

# %%
#Insight2:-
#Most of the movies are in English Language

# %%
data_groupby_duration = data.groupby(['duration'])['movie_title'].count()
data_groupby_duration.plot()

# %%
#Insight 3
#Majority of the movies are of 100 minutes around

# %%
print(data['content_rating'].value_counts())
data_content_rating=data['content_rating'].value_counts(dropna=False)
data_content_rating.plot(kind="bar")
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# TV-PG          13
# X              13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %%
#Insight4
#Majority of the movie are R rated

# %%
sns.factorplot(y='imdb_score',kind='box',data=data)
# Out:
# c:\users\saumya.shankar\tigerml\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.heatmap(data.corr())

# %%
#Insight5
#Above diagram shows the relation between variables present in the database with the help of correlation
#Light color-Positive high correlation because of same variable 
#Positive Correlation: both variables change in the same direction.(for ex cast_total_facebook likes vs actor1_facebook_likes)
#Neutral Correlation: No relationship in the change of the variables.
#Negative Correlation: variables change in opposite directions.
#(for example title_year vs duration this is actually little obvious too nowadays movies are shorter in comparison to 90's movies)

# %%
sns.set(style='whitegrid')
plt.figure(figsize = (12, 6))
sns.countplot(x="country", data = data)
ax = plt.xticks(rotation=90)

# %%
#INsights6:USA Tops the count

# %%
data_groupby_gross = data.groupby(['title_year'])['movie_facebook_likes'].count()
data_groupby_gross.plot()

# %%
#Insights7:
#Facebook likes increases nowadays for movies because of more involvement of people in social media nowadays
